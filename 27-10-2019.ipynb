# %% [markdown]
# ### (Revision)Series

# %%
import pandas as pd
ser1 = pd.Series([3,4,5,6,7],index=[10,20,30,40,50])
ser1
# Out:
# 10    3
# 20    4
# 30    5
# 40    6
# 50    7
# dtype: int64

# %% [markdown]
# ### DataFrame

# %%
df = pd.DataFrame([['APPLE'],['BANANA'],['MANGOES']])
df
# Out:
#          0
# 0    APPLE
# 1   BANANA
# 2  MANGOES

# %%
dict1 = {
    "City" : ['Karachi','Lahore','Islamabad','Quetta'],
    "Zip Code" : [1,2,3,4],
    "Population" : ['12345','23456','34567','45678']
}
dict1
# Out:
# {'City': ['Karachi', 'Lahore', 'Islamabad', 'Quetta'],
#  'Zip Code': [1, 2, 3, 4],
#  'Population': ['12345', '23456', '34567', '45678']}

# %%
df1 = pd.DataFrame(dict1, index = ['a','b','c','d'])
df1
# Out:
#         City  Zip Code Population
# a    Karachi         1      12345
# b     Lahore         2      23456
# c  Islamabad         3      34567
# d     Quetta         4      45678

# %%
df1 = pd.DataFrame(dict1, index = ['a','b','c','d'],columns = ['Population','Zip Code','City'])
df1
# Out:
#   Population  Zip Code       City
# a      12345         1    Karachi
# b      23456         2     Lahore
# c      34567         3  Islamabad
# d      45678         4     Quetta

# %%
df1["City"]
# Out:
# a      Karachi
# b       Lahore
# c    Islamabad
# d       Quetta
# Name: City, dtype: object

# %%
df1["City"] = "Faisalabad"
df1
# Out:
#   Population  Zip Code        City
# a      12345         1  Faisalabad
# b      23456         2  Faisalabad
# c      34567         3  Faisalabad
# d      45678         4  Faisalabad

# %%
df1 = pd.DataFrame(dict1, index = ['a','b','c','d'],columns = ['Population','Zip Code','City','covered area'])
df1
# Out:
#   Population  Zip Code       City covered area
# a      12345         1    Karachi          NaN
# b      23456         2     Lahore          NaN
# c      34567         3  Islamabad          NaN
# d      45678         4     Quetta          NaN

# %%
df1['Postal'] = 123
df1
# Out:
#   Population  Zip Code       City covered area  Postal
# a      12345         1    Karachi          NaN     123
# b      23456         2     Lahore          NaN     123
# c      34567         3  Islamabad          NaN     123
# d      45678         4     Quetta          NaN     123

# %%
df1.loc['c']
# Out:
# Population          34567
# Zip Code                3
# City            Islamabad
# covered area          NaN
# Postal                123
# Name: c, dtype: object

# %%
df1.iloc[2]
# Out:
# Population          34567
# Zip Code                3
# City            Islamabad
# covered area          NaN
# Postal                123
# Name: c, dtype: object

# %%
df1.loc['b':'d']
# Out:
#   Population  Zip Code       City covered area  Postal
# b      23456         2     Lahore          NaN     123
# c      34567         3  Islamabad          NaN     123
# d      45678         4     Quetta          NaN     123

# %%
df1.iloc[1:3]
# Out:
#   Population  Zip Code       City covered area  Postal
# b      23456         2     Lahore          NaN     123
# c      34567         3  Islamabad          NaN     123

# %%
df1.loc[['b','d','a']] #access random do fancy indexing
# Out:
#   Population  Zip Code     City covered area  Postal
# b      23456         2   Lahore          NaN     123
# d      45678         4   Quetta          NaN     123
# a      12345         1  Karachi          NaN     123

# %%
df1.iloc[[1,3,2]]
# Out:
#   Population  Zip Code       City covered area  Postal
# b      23456         2     Lahore          NaN     123
# d      45678         4     Quetta          NaN     123
# c      34567         3  Islamabad          NaN     123

# %%
df1['Zip Code']>2
# Out:
# a    False
# b    False
# c     True
# d     True
# Name: Zip Code, dtype: bool

# %%
df1[df1['Zip Code']>2]
#data["Ticket"][data["Parch"]==1]
# Out:
#   Population  Zip Code       City covered area  Postal
# c      34567         3  Islamabad          NaN     123
# d      45678         4     Quetta          NaN     123

# %% [markdown]
# ### Function Application and Mapping

# %%
import numpy as np
frame = pd.DataFrame(np.random.randn(4, 3), columns=list('bde'),index=['Utah', 'Ohio', 'Texas', 'Oregon'])
frame
# Out:
#                b         d         e
# Utah    0.589868 -1.468308  1.923097
# Ohio    0.208774 -1.260689  0.079695
# Texas  -0.377354  0.003650 -0.468740
# Oregon -0.681190 -0.116441  1.387605

# %%
frame.max()
# Out:
# b    0.589868
# d    0.003650
# e    1.923097
# dtype: float64

# %%
frame.min()
# Out:
# b   -0.681190
# d   -1.468308
# e   -0.468740
# dtype: float64

# %%
np.abs(frame)
# Out:
#                b         d         e
# Utah    0.589868  1.468308  1.923097
# Ohio    0.208774  1.260689  0.079695
# Texas   0.377354  0.003650  0.468740
# Oregon  0.681190  0.116441  1.387605

# %%
f = lambda x: x**2
frame.apply(f)
# Out:
#                b         d         e
# Utah    0.347945  2.155930  3.698301
# Ohio    0.043587  1.589337  0.006351
# Texas   0.142396  0.000013  0.219717
# Oregon  0.464020  0.013559  1.925447

# %%
f = lambda x: x.max() - x.min() #anonymous function, is called by assigned variable
frame.apply(f)
# Out:
# b    1.271059
# d    1.471958
# e    2.391837
# dtype: float64

# %%
#to find out min and max of row
frame.max(axis=1)
# Out:
# Utah      1.923097
# Ohio      0.208774
# Texas     0.003650
# Oregon    1.387605
# dtype: float64

# %% [markdown]
# ### Sorting and Ranking

# %% [markdown]
# ## Sorting

# %%
obj = pd.Series(range(4), index=['d', 'a', 'b', 'c'])
obj
# Out:
# d    0
# a    1
# b    2
# c    3
# dtype: int64

# %%
obj.sort_index()
# Out:
# a    1
# b    2
# c    3
# d    0
# dtype: int64

# %%
#The data is sorted in ascending order by default, but can be sorted in descending order, too
obj.sort_index(ascending=False)
# Out:
# d    0
# c    3
# b    2
# a    1
# dtype: int64

# %%
#shift+tab=signature
frame = pd.DataFrame(np.arange(8).reshape((2, 4)),index=['three', 'one'],columns=['d', 'a', 'b', 'c'])
frame
# Out:
#        d  a  b  c
# three  0  1  2  3
# one    4  5  6  7

# %%
frame.sort_index()
# Out:
#        d  a  b  c
# one    4  5  6  7
# three  0  1  2  3

# %%
frame.sort_index(axis=1)#column wise sort
# Out:
#        a  b  c  d
# three  1  2  3  0
# one    5  6  7  4

# %%
frame.sort_index(axis=1, ascending=False)
# Out:
#        d  c  b  a
# three  0  3  2  1
# one    4  7  6  5

# %%
frame1 = pd.DataFrame(np.arange(12,0,-1).reshape((3, 4)),index=['three', 'one','four'],columns=['d', 'a', 'b', 'c'])
frame1
# Out:
#         d   a   b  c
# three  12  11  10  9
# one     8   7   6  5
# four    4   3   2  1

# %%
frame1.sort_values(by = 'a')
# Out:
#        d  a  b  c
# one    4  3  2  1
# three  8  7  6  5

# %%
frame1.sort_values(by = ['a','b'])
# Out:
#         d   a   b  c
# four    4   3   2  1
# one     8   7   6  5
# three  12  11  10  9

# %%
data = pd.read_csv('jTeOBO.csv')
data
# Out:
#      Student Code  Degree                    Student Name  Mid  Quiz 1  \
# 0    022-14-19987  BS(CS)                     Abdul Basit   28     8.0
# 1   022-14-110233  BS(CS)                     Adeel Ahmed   17     NaN
# 2   022-14-110585  BS(CS)                    Afrah Zareen   18     5.0
# 3    022-14-19718  BS(CS)                  Ahmed Ali Raza   14     7.0
# 4   022-14-110648  BS(CS)                 Ahsan Ali Vohra   27     7.0
# 5   022-14-110232  BS(CS)                     Ameer Hamza   25     9.0
# 6   022-14-110588  BS(CS)                   Anas Ali Khan   28     5.0
# 7   022-14-110388  BS(CS)                Aneebullah Niazi   26     9.0
# 8   022-14-110601  BS(CS)                  Areesha Sohail   19     9.0
# 9   022-14-110599  BS(CS)                         Arsalan   28     8.0
# 10  022-14-110214  BS(CS)             Fatima Haider Warsi   30     8.0
# 11  022-14-110591  BS(CS)                     Habib Ullah   28     8.0
# ...

# %%
data.sort_values(by = 'Best of Quizzes')
# Out:
#      Student Code  Degree                    Student Name  Mid  Quiz 1  \
# 15   022-14-19916  BS(CS)                    Haseeb Sajid   18     NaN
# 32  022-14-110035  BS(CS)           Muhammad Wajahat Khan    9     NaN
# 33   022-14-19919  BS(CS)            Muhammad Younus Baig   20     4.0
# 39  022-14-110107  BS(CS)                     Sania Iqbal   28     4.0
# 24  022-14-110215  BS(CS)                  Muhammad Bilal   28     5.0
# 18  022-14-110223  BS(CS)                   Madiha Jabeen   16     5.0
# 16  022-14-110596  BS(CS)                    Hassam Ahmed   23     5.0
# 23   022-14-19983  BS(CS)              Muhammad Ali Iqbal   26     5.0
# 1   022-14-110233  BS(CS)                     Adeel Ahmed   17     NaN
# 2   022-14-110585  BS(CS)                    Afrah Zareen   18     5.0
# 26  022-14-110370  BS(CS)         Muhammad Ghazali Faridi   27     6.0
# 6   022-14-110588  BS(CS)                   Anas Ali Khan   28     5.0
# ...

# %%
data.sort_values(by = ['Best of Quizzes','Student Name'], ascending = False)
# Out:
#      Student Code  Degree                    Student Name  Mid  Quiz 1  \
# 15   022-14-19916  BS(CS)                    Haseeb Sajid   18     NaN
# 32  022-14-110035  BS(CS)           Muhammad Wajahat Khan    9     NaN
# 33   022-14-19919  BS(CS)            Muhammad Younus Baig   20     4.0
# 39  022-14-110107  BS(CS)                     Sania Iqbal   28     4.0
# 1   022-14-110233  BS(CS)                     Adeel Ahmed   17     NaN
# 2   022-14-110585  BS(CS)                    Afrah Zareen   18     5.0
# 16  022-14-110596  BS(CS)                    Hassam Ahmed   23     5.0
# 18  022-14-110223  BS(CS)                   Madiha Jabeen   16     5.0
# 23   022-14-19983  BS(CS)              Muhammad Ali Iqbal   26     5.0
# 24  022-14-110215  BS(CS)                  Muhammad Bilal   28     5.0
# 6   022-14-110588  BS(CS)                   Anas Ali Khan   28     5.0
# 26  022-14-110370  BS(CS)         Muhammad Ghazali Faridi   27     6.0
# ...

# %%
data.sort_values(by = ['Best of Quizzes','Assignment 1'])
# Out:
#      Student Code  Degree                    Student Name  Mid  Quiz 1  \
# 15   022-14-19916  BS(CS)                    Haseeb Sajid   18     NaN
# 32  022-14-110035  BS(CS)           Muhammad Wajahat Khan    9     NaN
# 33   022-14-19919  BS(CS)            Muhammad Younus Baig   20     4.0
# 39  022-14-110107  BS(CS)                     Sania Iqbal   28     4.0
# 16  022-14-110596  BS(CS)                    Hassam Ahmed   23     5.0
# 1   022-14-110233  BS(CS)                     Adeel Ahmed   17     NaN
# 2   022-14-110585  BS(CS)                    Afrah Zareen   18     5.0
# 18  022-14-110223  BS(CS)                   Madiha Jabeen   16     5.0
# 23   022-14-19983  BS(CS)              Muhammad Ali Iqbal   26     5.0
# 24  022-14-110215  BS(CS)                  Muhammad Bilal   28     5.0
# 38  022-14-110229  BS(CS)                Sadaquat Rafique    9     6.0
# 26  022-14-110370  BS(CS)         Muhammad Ghazali Faridi   27     6.0
# ...

# %%
#To sort a Series by its values, use its sort_values method:
obj = pd.Series([4,7,-3,2])
obj
# Out:
# 0    4
# 1    7
# 2   -3
# 3    2
# dtype: int64

# %%
#Any missing values are sorted to the end of the Series by default:
obj = pd.Series([4, np.nan, 7, np.nan, -3, 2])
obj
# Out:
# 0    4.0
# 1    NaN
# 2    7.0
# 3    NaN
# 4   -3.0
# 5    2.0
# dtype: float64

# %%
obj.sort_values()
# Out:
# 4   -3.0
# 5    2.0
# 0    4.0
# 2    7.0
# 1    NaN
# 3    NaN
# dtype: float64

# %%
frame = pd.DataFrame({'b': [4, 7, -3, 2], 'a': [0, 1, 0, 1]})
frame
# Out:
#    b  a
# 0  4  0
# 1  7  1
# 2 -3  0
# 3  2  1

# %%
frame.sort_values(by = 'b')
# Out:
#    b  a
# 2 -3  0
# 3  2  1
# 0  4  0
# 1  7  1

# %%
#To sort by multiple columns, pass a list of names:
frame.sort_values(by=['a', 'b'])
# Out:
#    b  a
# 2 -3  0
# 0  4  0
# 3  2  1
# 1  7  1

# %% [markdown]
# ## Ranking

# %%
#Ranking assigns ranks from one through the number of valid data points in an array.
#by default rank breaks ties by assigning each group the mean rank:
obj = pd.Series([7, -5, 7, 4, 2, 0, 4])
obj.rank()
# Out:
# 0    6.5
# 1    1.0
# 2    6.5
# 3    4.5
# 4    3.0
# 5    2.0
# 6    4.5
# dtype: float64

# %%
pd.options.display.max_rows = 10

# %%
data
# Out:
#      Student Code  Degree       Student Name  Mid  Quiz 1  Quiz 2  \
# 0    022-14-19987  BS(CS)        Abdul Basit   28     8.0     3.0
# 1   022-14-110233  BS(CS)        Adeel Ahmed   17     NaN     5.0
# 2   022-14-110585  BS(CS)       Afrah Zareen   18     5.0     2.0
# 3    022-14-19718  BS(CS)     Ahmed Ali Raza   14     7.0     2.0
# 4   022-14-110648  BS(CS)    Ahsan Ali Vohra   27     7.0     6.0
# ..            ...     ...                ...  ...     ...     ...
# 43  022-14-110451  BS(CS)  Syed Faizan Uddin   28     9.0     4.0
# 44  022-14-110589  BS(CS)        Syed Sohaib   25     7.0     5.0
# 45  022-14-110400  BS(CS)  Syeda Sabika Raza   27     9.0     6.0
# 46   022-14-19911  BS(CS)         Usman Khan   25     8.0     5.0
# 47  022-14-110219  BS(CS)        Waqar Ahmed   11     9.0     5.0
#
#     Best of Quizzes  Assignment 1  Assignment 2  Best of Assignments  \
# 0                 8           7.0           9.0                    9
# ...

# %%
obj.sort_values()
# Out:
# 1   -5
# 5    0
# 4    2
# 3    4
# 6    4
# 0    7
# 2    7
# dtype: int64

# %%
obj.sort_values(inplace = True)

# %%
obj
# Out:
# 1   -5
# 5    0
# 4    2
# 3    4
# 6    4
# 0    7
# 2    7
# dtype: int64

# %%
obj.rank(method = 'first')
# Out:
# 1    1.0
# 5    2.0
# 4    3.0
# 3    4.0
# 6    5.0
# 0    6.0
# 2    7.0
# dtype: float64

# %%
obj.rank()
# Out:
# 1    1.0
# 5    2.0
# 4    3.0
# 3    4.5
# 6    4.5
# 0    6.5
# 2    6.5
# dtype: float64

# %%
pd.options.display.max_rows = None # to show all data
data
# Out:
#      Student Code  Degree                    Student Name  Mid  Quiz 1  \
# 0    022-14-19987  BS(CS)                     Abdul Basit   28     8.0
# 1   022-14-110233  BS(CS)                     Adeel Ahmed   17     NaN
# 2   022-14-110585  BS(CS)                    Afrah Zareen   18     5.0
# 3    022-14-19718  BS(CS)                  Ahmed Ali Raza   14     7.0
# 4   022-14-110648  BS(CS)                 Ahsan Ali Vohra   27     7.0
# 5   022-14-110232  BS(CS)                     Ameer Hamza   25     9.0
# 6   022-14-110588  BS(CS)                   Anas Ali Khan   28     5.0
# 7   022-14-110388  BS(CS)                Aneebullah Niazi   26     9.0
# 8   022-14-110601  BS(CS)                  Areesha Sohail   19     9.0
# 9   022-14-110599  BS(CS)                         Arsalan   28     8.0
# 10  022-14-110214  BS(CS)             Fatima Haider Warsi   30     8.0
# 11  022-14-110591  BS(CS)                     Habib Ullah   28     8.0
# ...

# %%
arr = np.array([3,4,5,20,6,7,8])
np.max(arr)
# Out:
# 8

# %%
np.min(arr)
# Out:
# 3

# %%
arr.max()
# Out:
# 8

# %%
arr.min()
# Out:
# 3

# %%
print(f"The max value is {arr.max()}")
print()
print(f"The index of max value is {arr.argmax()}")
# Out:
# The max value is 8
#
# The index of max value is 5

# %%
data['Mid'].max()
# Out:
# 30

# %%
data['Mid'].idxmax() # the index of value 30 is 10 "returns index"
# Out:
# 10

# %% [markdown]
# ### Corelation and Covariance

# %%
import pandas_datareader.data as web

# %%
all_data = {ticker: web.get_data_yahoo(ticker) for ticker in ['AAPL', 'IBM', 'MSFT', 'GOOG']}
all_data
# Out:
# {'AAPL':                   High         Low        Open       Close       Volume  \
#  Date
#  2014-10-27  105.480003  104.699997  104.849998  105.110001   34187700.0
#  2014-10-28  106.739998  105.349998  105.400002  106.739998   48060900.0
#  2014-10-29  107.370003  106.360001  106.650002  107.339996   52687900.0
#  2014-10-30  107.349998  105.900002  106.959999  106.980003   40654800.0
#  2014-10-31  108.040001  107.209999  108.010002  108.000000   44639300.0
#  2014-11-03  110.300003  108.010002  108.220001  109.400002   52282600.0
#  2014-11-04  109.489998  107.720001  109.360001  108.599998   41574400.0
#  2014-11-05  109.300003  108.129997  109.099998  108.860001   37435900.0
#  2014-11-06  108.790001  107.800003  108.599998  108.699997   34968500.0
#  2014-11-07  109.320000  108.550003  108.750000  109.010002   33691500.0
#  2014-11-10  109.330002  108.669998  109.019997  108.830002   27195500.0
#  2014-11-11  109.750000  108.400002  108.699997  109.699997   27442300.0
# ...

# %%
price = pd.DataFrame({ticker: data['Adj Close'] for ticker, data in all_data.items()})
price
# Out:
#                   AAPL         IBM        MSFT         GOOG
# Date
# 2014-10-27   96.448616  131.081451   41.097130   539.289368
# 2014-10-28   97.944298  132.482391   41.616329   547.397095
# 2014-10-29   98.494850  132.369003   41.732697   547.825928
# 2014-10-30   98.164513  133.089706   41.222458   548.803284
# 2014-10-31   99.100471  133.130219   42.028111   557.549255
# 2014-11-03  100.385109  133.097809   42.466732   553.699829
# 2014-11-04   99.651047  131.713089   42.583115   552.592834
# 2014-11-05   99.889618  131.040939   42.842709   544.425293
# 2014-11-06  100.175293  131.644287   43.594646   540.555908
# 2014-11-07  100.460983  132.141617   43.576752   539.528748
# 2014-11-10  100.295105  133.299408   43.764729   545.990967
# 2014-11-11  101.096870  133.144485   43.746830   548.783325
# 2014-11-12  102.525322  132.019318   43.666264   545.811462
# 2014-11-13  103.972198  132.728683   44.409256   543.886780
# 2014-11-14  105.225540  133.845688   44.382393   542.909424
# ...

# %%
volume = pd.DataFrame({ticker: data['Volume'] for ticker, data in all_data.items()})
volume
# Out:
#                    AAPL         IBM         MSFT        GOOG
# Date
# 2014-10-27   34187700.0   4989100.0   30371300.0   1185300.0
# 2014-10-28   48060900.0   7895300.0   29049800.0   1270900.0
# 2014-10-29   52687900.0   4739300.0   30276100.0   1770500.0
# 2014-10-30   40654800.0   3896000.0   30073900.0   1455600.0
# 2014-10-31   44639300.0   5818000.0   35849700.0   2035000.0
# 2014-11-03   52282600.0   4688200.0   23130400.0   1382200.0
# 2014-11-04   41574400.0   4246900.0   21530800.0   1244200.0
# 2014-11-05   37435900.0   4104700.0   22449600.0   2032200.0
# 2014-11-06   34968500.0   4067600.0   33037800.0   1333200.0
# 2014-11-07   33691500.0   3494800.0   28000600.0   1633700.0
# 2014-11-10   27195500.0   4958200.0   36370100.0   1134600.0
# 2014-11-11   27442300.0   3534400.0   23445200.0    965500.0
# 2014-11-12   46942400.0   3378200.0   22722100.0   1129600.0
# 2014-11-13   59522900.0   3239700.0   26210400.0   1339300.0
# ...

# %%
#percentage changes how much values are changed
returns = price.pct_change()
returns
# Out:
#                 AAPL       IBM      MSFT      GOOG
# Date
# 2014-10-27       NaN       NaN       NaN       NaN
# 2014-10-28  0.015508  0.010688  0.012633  0.015034
# 2014-10-29  0.005621 -0.000856  0.002796  0.000783
# 2014-10-30 -0.003354  0.005445 -0.012226  0.001784
# 2014-10-31  0.009535  0.000304  0.019544  0.015936
# 2014-11-03  0.012963 -0.000243  0.010436 -0.006904
# 2014-11-04 -0.007312 -0.010404  0.002741 -0.001999
# 2014-11-05  0.002394 -0.005103  0.006096 -0.014780
# 2014-11-06  0.002860  0.004604  0.017551 -0.007107
# 2014-11-07  0.002852  0.003778 -0.000410 -0.001900
# 2014-11-10 -0.001651  0.008762  0.004314  0.011978
# 2014-11-11  0.007994 -0.001162 -0.000409  0.005114
# 2014-11-12  0.014130 -0.008451 -0.001842 -0.005415
# 2014-11-13  0.014112  0.005373  0.017015 -0.003526
# 2014-11-14  0.012055  0.008416 -0.000605 -0.001797
# 2014-11-17 -0.001664  0.000000 -0.002420 -0.014493
# 2014-11-18  0.012984 -0.013828 -0.008342 -0.002758
# ...

# %%
returns['MSFT'].corr(returns['IBM'])
# Out:
# 0.48590442370509673

# %%
returns['MSFT'].cov(returns['IBM'])
# Out:
# 9.367689618560125e-05

# %%
returns.corr()# from all
# Out:
#           AAPL       IBM      MSFT      GOOG
# AAPL  1.000000  0.405686  0.572626  0.520823
# IBM   0.405686  1.000000  0.485904  0.412926
# MSFT  0.572626  0.485904  1.000000  0.655260
# GOOG  0.520823  0.412926  0.655260  1.000000

# %%
returns.cov()
# Out:
#           AAPL       IBM      MSFT      GOOG
# AAPL  0.000246  0.000083  0.000133  0.000124
# IBM   0.000083  0.000170  0.000094  0.000082
# MSFT  0.000133  0.000094  0.000219  0.000147
# GOOG  0.000124  0.000082  0.000147  0.000230

# %%
returns.corrwith(returns.IBM)
# Out:
# AAPL    0.405686
# IBM     1.000000
# MSFT    0.485904
# GOOG    0.412926
# dtype: float64

# %% [markdown]
# ### Unique Values, Values Count
